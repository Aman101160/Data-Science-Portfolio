# %% [markdown]
# # Budget Analysis for the Month of September

# %%
import os 
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
September_Budget = pd.read_csv("Budget_Expenses_August.csv")

# %%
September_Budget
# Out:
#          Date  Rent   Auto Insurance  Car Payments   Gas  Groceries  Haircut  \
# 0    9/1/2020    NaN             NaN        11.833   NaN        NaN      NaN
# 1    9/2/2020    NaN          134.54        11.833   NaN      63.00      NaN
# 2    9/3/2020    NaN             NaN        11.833   NaN        NaN      NaN
# 3    9/4/2020    NaN             NaN        11.833   NaN        NaN      NaN
# 4    9/5/2020    NaN             NaN        11.833   NaN        NaN      NaN
# 5    9/6/2020    NaN             NaN        11.833  19.0        NaN      NaN
# 6    9/7/2020    NaN             NaN        11.833   NaN      19.51      NaN
# 7    9/8/2020    NaN             NaN        11.833   NaN        NaN      NaN
# 8    9/9/2020    NaN             NaN        11.833   NaN      13.00      NaN
# 9   9/10/2020    NaN             NaN        11.833   NaN        NaN     31.0
# 10  9/11/2020    NaN             NaN        11.833   NaN        NaN      NaN
# ...

# %%
September_Budget.fillna(0, inplace = True)

# %% [markdown]
# Replace the NaNs with 0s. That is the empty rows where I did not spend $ on anything.

# %%
September_Budget = September_Budget.head(10)

# %%
September_Budget
# Out:
#         Date  Rent   Auto Insurance  Car Payments   Gas  Groceries  Haircut  \
# 0   9/1/2020    0.0            0.00        11.833   0.0       0.00      0.0
# 1   9/2/2020    0.0          134.54        11.833   0.0      63.00      0.0
# 2   9/3/2020    0.0            0.00        11.833   0.0       0.00      0.0
# 3   9/4/2020    0.0            0.00        11.833   0.0       0.00      0.0
# 4   9/5/2020    0.0            0.00        11.833   0.0       0.00      0.0
# 5   9/6/2020    0.0            0.00        11.833  19.0       0.00      0.0
# 6   9/7/2020    0.0            0.00        11.833   0.0      19.51      0.0
# 7   9/8/2020    0.0            0.00        11.833   0.0       0.00      0.0
# 8   9/9/2020    0.0            0.00        11.833   0.0      13.00      0.0
# 9  9/10/2020    0.0            0.00        11.833   0.0       0.00     31.0
#
#    Clothing  Credit Card Debt  Loans  Online Shopping  Take-out  Donations  \
# ...

# %%
del September_Budget['Rent ']
del September_Budget['Clothing']
del September_Budget['Loans']
del September_Budget['Donations']
del September_Budget['Online Shopping']
del September_Budget['Personal Development']

# %%
September_Budget
# Out:
#         Date  Auto Insurance  Car Payments   Gas  Groceries  Haircut  \
# 0   9/1/2020            0.00        11.833   0.0       0.00      0.0
# 1   9/2/2020          134.54        11.833   0.0      63.00      0.0
# 2   9/3/2020            0.00        11.833   0.0       0.00      0.0
# 3   9/4/2020            0.00        11.833   0.0       0.00      0.0
# 4   9/5/2020            0.00        11.833   0.0       0.00      0.0
# 5   9/6/2020            0.00        11.833  19.0       0.00      0.0
# 6   9/7/2020            0.00        11.833   0.0      19.51      0.0
# 7   9/8/2020            0.00        11.833   0.0       0.00      0.0
# 8   9/9/2020            0.00        11.833   0.0      13.00      0.0
# 9  9/10/2020            0.00        11.833   0.0       0.00     31.0
#
#    Credit Card Debt  Take-out  Misc
# 0              0.00       0.0   0.00
# 1             60.00       0.0   0.00
# 2              0.00       0.0   0.00
# 3              0.00       0.0   0.00
# ...

# %%
sns.pairplot(September_Budget)

# %%
sns.distplot(September_Budget[['Groceries']])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x = September_Budget['Groceries'])
# Out:
# <AxesSubplot:xlabel='Groceries'>

# %%
SnS_Groceries = September_Budget[September_Budget['Groceries'] < 63]

# %% [markdown]
# Removing the outlier

# %%
sns.boxplot(x = SnS_Groceries['Groceries'])
# Out:
# <AxesSubplot:xlabel='Groceries'>

# %%
corr = September_Budget.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %% [markdown]
# There seems to be a weak correlation among the variables.

# %%
September_Budget.plot(kind = 'scatter', x = 'Groceries' , y = 'Credit Card Debt')
# Out:
# <AxesSubplot:xlabel='Groceries', ylabel='Credit Card Debt'>

# %%
September_Budget.plot(kind = 'scatter', x = 'Car Payments' , y = 'Groceries')
# Out:
# <AxesSubplot:xlabel='Car Payments', ylabel='Groceries'>

# %%
September_Budget.describe()
# Out:
#        Auto Insurance  Car Payments        Gas  Groceries    Haircut  \
# count       10.000000        10.000  10.000000  10.000000  10.000000
# mean        13.454000        11.833   1.900000   9.551000   3.100000
# std         42.545284         0.000   6.008328  20.017837   9.803061
# min          0.000000        11.833   0.000000   0.000000   0.000000
# 25%          0.000000        11.833   0.000000   0.000000   0.000000
# 50%          0.000000        11.833   0.000000   0.000000   0.000000
# 75%          0.000000        11.833   0.000000   9.750000   0.000000
# max        134.540000        11.833  19.000000  63.000000  31.000000
#
#        Credit Card Debt   Take-out      Misc
# count          10.00000  10.000000  10.000000
# mean           21.05500   0.300000   1.167000
# std            36.08966   0.948683   2.492291
# min             0.00000   0.000000   0.000000
# 25%             0.00000   0.000000   0.000000
# 50%             0.00000   0.000000   0.000000
# ...
